# %% [markdown]
# ### Importar as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


#MAPEAMENTO DO CAMINHO DO ARQUIVO
path = 'c:\\Users\\FIC\CURSO PYTHON - FELIPE MUNHOS\\Arquivos\\'
file ='IceCreamData.csv'

# ATRIBUIR O ARQUIVO A UM DATAFRAME
iceCream = pd.read_csv (path + file)

# Verificar o cabeçalho
iceCream.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %% [markdown]
# ### Visualizar o cabeçalho e o final do Dataframa

# %%
#Verificar as primeiras linhas do DataFrame

iceCream.head(2)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122

# %%
#Verificar as ultimas linhas do DataFrame
iceCream.tail(2)
# Out:
#      Temperature     Revenue
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %% [markdown]
# ### Descever os dados numéricos do dataframe

# %%
iceCream.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %% [markdown]
# ### Obter informações do DataFrame

# %%
iceCream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %% [markdown]
# ### PASSO 03 - Visualizar os dados do Dataset

# %%
### Grafico de dispersão e histograma

sns.jointplot( x = "Temperature", y= "Revenue", data = iceCream, color = "gray")
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(iceCream)
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# ### Grafico de dispersão com a linha media

# %%
sns.lmplot( x = "Temperature", 
            y= "Revenue", 
            data = iceCream,
)

# %% [markdown]
# ### Passo 04 - Dividir o dataset para criar s bases de treino

# %%
 x = iceCream[['Temperature']]
 y = iceCream["Revenue"]

# %% [markdown]
# ### PASSO 05 - MODELO TREINO
# IMPORTAR A BIBLIOTECA SCIKIT LEARN E DIVIDIR AS BASES EM TREINOS E TESTE, SENDO QUE O TAMANHO DO TESTE SERÁ DE 25%

# %%
X_train, X_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
X_train.shape
# Out:
# (375, 1)

# %% [markdown]
# ### Importar o algoritmo LinearRegression da biblioteca Scikitlearn

# %%
from sklearn.linear_model import LinearRegression

# %%
# Este comando irá gerar a linha de tendência
# E calcular os coefientes linear e angular

regressor = LinearRegression(fit_intercept = True )

regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coeficiente angular (a):', regressor.coef_)
print('Coeficiente linear (b):', regressor.intercept_)
# Out:
# Coeficiente angular (a): [21.36569093]
# Coeficiente linear (b): 46.67098449900908

# %% [markdown]
# ### PASSO 06 - Executar o teste

# %%
y_previsao = regressor.predict(X_test)
y_previsao
# Out:
# array([458.34053276, 576.07431682, 705.46037271, 494.2376294 ,
#        523.36259619, 182.39566805, 661.7913951 , 558.9333272 ,
#        664.14354871, 259.35269982, 681.62761663, 589.77193328,
#        524.99760675, 620.84372238, 238.78615198, 509.87696392,
#        736.72578261, 661.85671194, 896.25906513, 468.17499087,
#        441.1437445 , 452.30450629, 571.16785683, 531.21409042,
#        453.88580991, 670.22962838, 554.35048051, 447.85092416,
#        862.52415205, 591.48934641, 689.37424228, 519.97634783,
#        558.67582747, 443.60533788, 774.42217105, 391.63767273,
#        423.95708721, 547.15475638, 416.28042714, 191.42794859,
#        672.94238529, 514.52476317, 388.35853122, 640.22055144,
#        307.10632065, 305.68755502, 233.73944389, 767.63931838,
#        473.50337668, 240.53980809, 412.72499542, 696.78178075,
#        762.73228386, 438.66345656, 712.42655966, 527.03150366,
#        368.18026335, 579.73888813, 396.63188397, 453.14494155,
# ...

# %%
y_test
# Out:
# 143    486.474985
# 269    594.804871
# 7      696.716640
# 46     500.925065
# 315    520.392405
#           ...
# 418    679.712058
# 332    379.564268
# 0      534.799028
# 479    432.819795
# 454    756.962562
# Name: Revenue, Length: 125, dtype: float64

# %% [markdown]
# ### Plotando os resultados

# %%
plt.scatter(X_train,y_train,color = "blue")
plt.plot(X_train,regressor.predict(X_train),color = 'red')
plt.ylabel('Receita[Dólares]')
plt.xlabel('Temperatura [ºC]')
plt.title('Receita gerada vs. Temperatura (Vendas de soverte)')
# Out:
# Text(0.5, 1.0, 'Receita gerada vs. Temperatura (Vendas de soverte)')
